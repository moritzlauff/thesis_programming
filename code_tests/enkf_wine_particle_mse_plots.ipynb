# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.insert(1, "../python/functions")
sys.path.insert(2, "../python/architecture")

# %%
from saving_functions import load_objects
from model_functions import nn_model_structure, nn_model_compile
from plotting_functions import nn_plot_particle_mse
import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From ../python/architecture\reproducible.py:14: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
model_object_path = "../objects/wine/wine_enkf_full_E20_B200_P500_H2.pckl"

# %%
nn_plot_particle_mse(model_object_path,
                     train_test = "train",
                     rel_limit_exceed = 0.01,
                     return_mses = False,
                     save = None)

# %%
nn_plot_particle_mse(model_object_path,
                     train_test = "test",
                     rel_limit_exceed = 0.01,
                     return_mses = False,
                     save = None)
