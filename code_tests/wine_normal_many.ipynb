# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.insert(1, "../python/functions")
sys.path.insert(2, "../python/architecture")

# %%
from model_functions import nn_load
from plotting_functions import nn_plot_mse_many
# Out:
# WARNING:tensorflow:From ../python/architecture\reproducible.py:14: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
model_dict = {}
batches = [100, 200, 500, 1000, 2000, 4163]

for b in batches:
    model_dict["batch_size: {}".format(b)] = nn_load("../models/wine/wine_sgd_E20_B{}.h5".format(b))

# %%
model_list = list(model_dict.values())
label_list = ["B{}".format(list(model_dict.keys())[i].split(": ")[1]) for i in range(len(model_dict))]

nn_plot_mse_many(model_list,
                 label_list,
                 train_test = "train",
                 mse_mean = None,
                 start_epoch = 1,
                 save = None)#"../img/wine/wine_sgd_batches.png")
