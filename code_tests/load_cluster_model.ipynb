# %%
from tensorflow.keras.models import load_model
model = load_model("../models/test_model.h5", compile = False)
model.get_weights()
# Out:
# [array([[-0.01946323, -0.038839  ,  0.02646868, ...,  0.0730798 ,
#          -0.00226686,  0.03223316],
#         [ 0.01142125,  0.03969434, -0.01284365, ...,  0.04149543,
#           0.06243091,  0.01843173],
#         [-0.01898882,  0.00646532, -0.00736677, ..., -0.02516621,
#           0.00460425, -0.02938843],
#         ...,
#         [-0.03558764,  0.08153851, -0.04634209, ..., -0.06510037,
#           0.04905931,  0.0480242 ],
#         [ 0.01507735,  0.03222376,  0.01691341, ..., -0.0441507 ,
#           0.07225873,  0.03247778],
#         [ 0.07467708,  0.0017213 ,  0.00846703, ...,  0.05775199,
#          -0.0213984 ,  0.07590587]], dtype=float32),
#  array([ 0.07231794,  0.03521224, -0.00101111, -0.13871162,  0.08381189,
#         -0.1352732 ,  0.05597335,  0.03395102, -0.06860022,  0.10358924,
#         -0.11760739,  0.00544916,  0.10802815,  0.09059586,  0.00387322,
#          0.08057003, -0.07214171, -0.04225569,  0.08681636, -0.05426169,
# ...
