# %%
import sys
sys.path.insert(1, "../python/architecture")
sys.path.insert(2, "../python/functions")

# %%
from saving_functions import load_objects

# %%
model = "../objects/wine/wine_enkf_full_E20_B100_P500_H2_history.pckl"
result = load_objects(model)

# %%
result
# Out:
# {'mse': array([0.63928324, 0.66439557, 0.55670595, 0.53491437, 0.48505464,
#         0.46067888, 0.44201469, 0.43151623, 0.42323413, 0.41713625,
#         0.41213053, 0.40803877, 0.40493119, 0.40229383, 0.39984259,
#         0.39765555, 0.39582887, 0.39413783, 0.39258778, 0.39125222]),
#  'val_mse': array([0.65195101, 0.7025615 , 0.6027211 , 0.58819705, 0.54673785,
#         0.52397978, 0.50567406, 0.49625975, 0.49137598, 0.48680279,
#         0.48079041, 0.47924009, 0.47758415, 0.47707105, 0.47722483,
#         0.47744405, 0.47718289, 0.47678566, 0.47599706, 0.47512078])}

# %%
model = "../objects/wine/wine_sgd_E20_B100_history.pckl"
result = load_objects(model)

# %%
result
# Out:
# {'loss': [2.916795492172241,
#   0.7484890818595886,
#   0.6460525393486023,
#   0.5948748588562012,
#   0.5669758319854736,
#   0.5494419932365417,
#   0.5344072580337524,
#   0.5251912474632263,
#   0.5191507935523987,
#   0.51576167345047,
#   0.5103098154067993,
#   0.5053689479827881,
#   0.5012720227241516,
#   0.49736037850379944,
#   0.49745237827301025,
#   0.49737948179244995,
#   0.49153658747673035,
#   0.49178582429885864,
#   0.48844587802886963,
#   0.4876891076564789],
#  'mse': [2.916795492172241,
#   0.7484890818595886,
#   0.6460525393486023,
#   0.5948748588562012,
#   0.5669758319854736,
#   0.5494419932365417,
#   0.5344072580337524,
#   0.5251912474632263,
#   0.5191507935523987,
#   0.51576167345047,
#   0.5103098154067993,
#   0.5053689479827881,
#   0.5012720227241516,
#   0.4973604381084442,
#   0.49745237827301025,
#   0.49737948179244995,
#   0.49153658747673035,
#   0.49178582429885864,
#   0.48844587802886963,
#   0.4876891076564789],
# ...
